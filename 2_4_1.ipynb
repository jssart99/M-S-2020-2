# %% [markdown]
# <a href="https://colab.research.google.com/github/jssart99/M-S-2020-2/blob/master/2_4_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 2.4.1

# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.integrate import solve_ivp

# %%
# Método de Runge Kutta

def rk4( func, h, ti, tf, x0, par ):
    ti = ti
    xi = x0
  
    x = list()
    t = list()
  
    while ( ti < tf ):

      x.append (xi)
      t.append (ti)
      k1 = func( ti,xi,par)
      k2 = func( ti + 0.5*h,xi + 0.5*k1*h,par )
      k3 = func( ti + 0.5*h,xi + 0.5*k2*h,par)
      k4 = func( ti + h,xi + k3*h,par) 

      xi = xi + h*(k1 + 2*k2 + 2*k3 + k4)/6
      ti = ti + h
    return t, x


# Método de Euler 

def euler( func, h, ti, tf, x0, par ):
    ti = ti 
    xi = x0
  
    x = list()
    t = list()
  
    while ( ti < tf ):
    
      x.append (xi)
      t.append (ti)
  
      xi = xi + h*func(ti,xi,par)
      ti = ti + h
    return t, x

# %%
def sistema1(t, x, a):
    x_dot = x*(1-x)
    return x_dot

# %%
a = 0.5
h = 0.0008
ti = 0
tf = 1
x0 = 0

plt.figure(figsize=(5, 5), dpi=100)
for i in range(0,15,1):
    x0=i
    t1,x1 = euler( sistema1, h, ti, tf, x0 ,a )
    t2,x2 = rk4( sistema1, h, ti, tf, x0 ,a)
    if i==0:
      plt.plot( t1, x1, c = 'crimson', label = 'Euler', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', label = 'RK4', linewidth = 2)
    else:
      plt.plot( t1, x1, c = 'crimson', linewidth = 2)
      plt.plot( t2, x2, c = 'royalblue', linewidth = 2)


plt.xlim([0, tf])
plt.xlabel(r'$t$')
plt.grid()
plt.legend(loc = 'best')
plt.show()

# %% [markdown]
# <a href="https://colab.research.google.com/github/jssart99/M-S-2020-2/blob/master/Ejercicios_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Modelado y simulación ejercicios capitulo 2--2.2

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.integrate import solve_ivp

# %%
#2.2.1 
x=np.arange(-2.5,2.5,0.1)
dx=4*x**2-16

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

plt.plot(x,dx)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def dx(t,x):
  return 4*x**2-16
x_0=np.arange(-2.5,1.99,0.1)
ts=[0,1]
sol = solve_ivp(dx, ts, x_0, \
                dense_output = True)

t = np.linspace(ts[0],ts[1],100)
x = sol.sol(t)
for i in range(x_0.size):
  plt.plot(t,x[i])
plt.show()

# %%
#2.2.3
x=np.arange(-1.2,1.2,0.1)
dx=x-x**3

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

plt.plot(x,dx)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
def dx(t,x):
  return x-x**3
x_0=np.arange(-1.4,1.6,0.2)
ts=[0,8]
sol = solve_ivp(dx, ts, x_0, \
                dense_output = True)

t = np.linspace(ts[0],ts[1],100)
x = sol.sol(t)
for i in range(x_0.size):
  plt.plot(t,x[i])
plt.show()

# %%
#2.2.5
x=np.arange(-5*np.pi,5*np.pi,np.pi/10)
dx=1+(np.cos(x)/2)

fig=plt.figure()
ax=fig.add_subplot(1,1,1)

ax.spines['left'].set_position(('data',0.0))
ax.spines['bottom'].set_position(('data',0.0))
ax.spines['top'].set_color('none')
ax.spines['right'].set_color('none')

plt.plot(x,dx)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %% [markdown]
# No hay fixed points

# %%
def dx(t,x):
  return 1+(np.cos(x)/2)
x_0=np.arange(-5*np.pi,5*np.pi,np.pi)
ts=[0,8]
sol = solve_ivp(dx, ts, x_0, \
                dense_output = True)

t = np.linspace(ts[0],ts[1],100)
x = sol.sol(t)
for i in range(x_0.size):
  plt.plot(t,x[i])
plt.show()
